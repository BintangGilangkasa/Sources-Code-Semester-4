# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
training_df = pd.read_csv('training_dataset.csv')
validation_df = pd.read_csv('validation_set.csv')

training_df.head(), validation_df.head()
# Out:
# (   customer_number  usia               pekerjaan status_perkawinan  \
#  0           531036    63  sosial media specialis           menikah
#  1           999241    43                 teknisi           menikah
#  2           995002    29  sosial media specialis            lajang
#  3           932750    40           pekerja kasar           menikah
#  4           684699    40  sosial media specialis            lajang
#
#            pendidikan gagal_bayar_sebelumnya pinjaman_rumah pinjaman_pribadi  \
#  0  Pendidikan Tinggi                     no            yes               no
#  1  Pendidikan Tinggi                     no            yes               no
#  2  Pendidikan Tinggi                     no            yes              yes
#  3                SMA                     no             no               no
#  4  Pendidikan Tinggi                     no             no               no
#
#    jenis_kontak bulan_kontak_terakhir  ... hari_sejak_kontak_sebelumnya  \
#  0     cellular                   jul  ...                          999
#  1     cellular                   nov  ...                          999
#  2     cellular                   jul  ...                          999
#  3    telephone                   may  ...                          999
#  4     cellular                   aug  ...                          999
#
#     jumlah_kontak_sebelumnya  hasil_kampanye_sebelumnya  \
#  0                         0                nonexistent
#  1                         0                nonexistent
#  2                         0                nonexistent
#  3                         0                nonexistent
#  4                         0                nonexistent
#
#     tingkat_variasi_pekerjaan indeks_harga_konsumen  \
#  0                       -1.7                94.215
#  1                       -0.1                93.200
#  2                        1.4                93.918
#  3                        1.1                93.994
#  4                        1.4                93.444
#
#     indeks_kepercayaan_konsumen  suku_bunga_euribor_3bln  jumlah_pekerja  \
#  0                        -40.3                    0.885          4991.6
#  1                        -42.0                    4.021          5195.8
#  2                        -42.7                    4.958          5228.1
#  3                        -36.4                    4.859          5191.0
#  4                        -36.1                    4.964          5228.1
#
#        pulau  berlangganan_deposito
#  0     Papua                      1
#  1  Sulawesi                      0
#  2     Papua                      0
#  3  Sumatera                      1
#  4      Bali                      0
#
#  [5 rows x 22 columns],
#     customer_number  usia      pekerjaan status_perkawinan pendidikan  \
#  0           445420    35  penyedia jasa           menikah        SMA
#  1           585604    52        teknisi            lajang    Diploma
#  2           888824    37  pekerja kasar           menikah        SMP
#  3           816820    51   pengangguran           menikah    Diploma
#  4           542716    45        teknisi             cerai        SMA
#
#    gagal_bayar_sebelumnya pinjaman_rumah pinjaman_pribadi jenis_kontak  \
#  0                     no            yes              yes     cellular
#  1                unknown             no               no    telephone
#  2                unknown            yes               no    telephone
#  3                     no             no               no    telephone
#  4                     no            yes               no     cellular
#
#    bulan_kontak_terakhir  ... jumlah_kontak_kampanye_ini  \
#  0                   jul  ...                          1
#  1                   may  ...                          4
#  2                   may  ...                          3
#  3                   may  ...                          3
#  4                   may  ...                          1
#
#     hari_sejak_kontak_sebelumnya  jumlah_kontak_sebelumnya  \
#  0                           999                         0
#  1                           999                         0
#  2                           999                         0
#  3                           999                         0
#  4                           999                         1
#
#     hasil_kampanye_sebelumnya tingkat_variasi_pekerjaan  indeks_harga_konsumen  \
#  0                nonexistent                       1.4                 93.918
#  1                nonexistent                       1.1                 93.994
#  2                nonexistent                       1.1                 93.994
#  3                nonexistent                       1.1                 93.994
#  4                    failure                      -1.8                 92.893
#
#     indeks_kepercayaan_konsumen  suku_bunga_euribor_3bln  jumlah_pekerja  \
#  0                        -42.7                    4.960          5228.1
#  1                        -36.4                    4.860          5191.0
#  2                        -36.4                    4.856          5191.0
#  3                        -36.4                    4.857          5191.0
#  4                        -46.2                    1.327          5099.1
#
#        pulau
#  0      Jawa
#  1     Papua
#  2      Bali
#  3  Sumatera
#  4  Sumatera
#
#  [5 rows x 21 columns])

# %%
X = training_df.drop(columns=['berlangganan_deposito'])
y = training_df['berlangganan_deposito']

# %%
# Identifikasi kolom numerik dan kategorikal
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns.tolist()
numeric_features.remove("customer_number")  # Jangan ubah customer_number
categorical_features = X.select_dtypes(include=["object"]).columns.tolist()

# Buat preprocessing pipeline
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="mean")),
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer(transformers=[
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features)
])

# Buat pipeline model
model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("classifier", RandomForestClassifier(random_state=42))
])

# Latih model
model.fit(X.drop(columns=["customer_number"]), y)

# Prediksi probabilitas pada validation set
X_val = validation_df.drop(columns=["customer_number"])
prob_predictions = model.predict_proba(X_val)[:, 1]  # Probabilitas kelas 1

# Buat dataframe hasil
submission_df = pd.DataFrame({
    "customer_number": validation_df["customer_number"],
    "berlangganan_deposito": prob_predictions
})

# Simpan sebagai CSV
submission_path = "prediksi_berlangganan.csv"
submission_df.to_csv(submission_path, index=False)

submission_df.head(), submission_path
# Out:
# (   customer_number  berlangganan_deposito
#  0           445420                   0.04
#  1           585604                   0.07
#  2           888824                   0.02
#  3           816820                   0.02
#  4           542716                   0.05,
#  'prediksi_berlangganan.csv')

# %%
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier

# Ganti model dalam pipeline menjadi XGBoostClassifier untuk akurasi lebih tinggi
xgb_model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("classifier", XGBClassifier(
        objective="binary:logistic",
        eval_metric="logloss",
        use_label_encoder=False,
        random_state=42,
        n_estimators=100,
        max_depth=5,
        learning_rate=0.1
    ))
])

# Cross-validation untuk estimasi akurasi
scores = cross_val_score(
    xgb_model,
    X.drop(columns=["customer_number"]),
    y,
    cv=5,
    scoring="roc_auc"
)

# Latih ulang model di seluruh data
xgb_model.fit(X.drop(columns=["customer_number"]), y)

# Prediksi probabilitas pada validation set
xgb_prob_predictions = xgb_model.predict_proba(X_val)[:, 1]

# Buat file hasil prediksi
xgb_submission_df = pd.DataFrame({
    "customer_number": validation_df["customer_number"],
    "berlangganan_deposito": xgb_prob_predictions
})

xgb_submission_path = "/mnt/data/prediksi_xgboost_berlangganan.csv"
xgb_submission_df.to_csv(xgb_submission_path, index=False)

scores.mean(), xgb_submission_df.head(), xgb_submission_path
# Out:
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_tags.py:354: FutureWarning: The XGBClassifier or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\core.py:158: UserWarning: [18:01:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_tags.py:354: FutureWarning: The XGBClassifier or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_response.py", line 235, in _get_response_values
#     raise ValueError(
# ValueError: Pipeline should either be a classifier to be used with response_method=predict_proba or the response_method should be 'predict'. Got a regressor with response_method=predict_proba instead.
#
#   warnings.warn(
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\core.py:158: UserWarning: [18:01:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_tags.py:354: FutureWarning: The XGBClassifier or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_response.py", line 235, in _get_response_values
#     raise ValueError(
# ValueError: Pipeline should either be a classifier to be used with response_method=predict_proba or the response_method should be 'predict'. Got a regressor with response_method=predict_proba instead.
#
#   warnings.warn(
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\core.py:158: UserWarning: [18:01:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_tags.py:354: FutureWarning: The XGBClassifier or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_response.py", line 235, in _get_response_values
#     raise ValueError(
# ValueError: Pipeline should either be a classifier to be used with response_method=predict_proba or the response_method should be 'predict'. Got a regressor with response_method=predict_proba instead.
#
#   warnings.warn(
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\core.py:158: UserWarning: [18:01:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_tags.py:354: FutureWarning: The XGBClassifier or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_response.py", line 235, in _get_response_values
#     raise ValueError(
# ValueError: Pipeline should either be a classifier to be used with response_method=predict_proba or the response_method should be 'predict'. Got a regressor with response_method=predict_proba instead.
#
#   warnings.warn(
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\core.py:158: UserWarning: [18:01:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_tags.py:354: FutureWarning: The XGBClassifier or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_response.py", line 235, in _get_response_values
#     raise ValueError(
# ValueError: Pipeline should either be a classifier to be used with response_method=predict_proba or the response_method should be 'predict'. Got a regressor with response_method=predict_proba instead.
#
#   warnings.warn(
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\core.py:158: UserWarning: [18:01:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\62822\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_tags.py:354: FutureWarning: The XGBClassifier or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 31
#      28 xgb_model.fit(X.drop(columns=["customer_number"]), y)
#      30 # Prediksi probabilitas pada validation set
# ---> 31 xgb_prob_predictions = xgb_model.predict_proba(X_val)[:, 1]
#      33 # Buat file hasil prediksi
#      34 xgb_submission_df = pd.DataFrame({
#      35     "customer_number": validation_df["customer_number"],
#      36     "berlangganan_deposito": xgb_prob_predictions
#      37 })
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\pipeline.py:896, in Pipeline.predict_proba(self, X, **params)
#     859 """Transform the data, and apply `predict_proba` with the final estimator.
#     860
#     861 Call `transform` of each transformer in the pipeline. The transformed
#    (...)
#     893     Result of calling `predict_proba` on the final estimator.
#     894 """
#     895 # TODO(1.8): Remove the context manager and use check_is_fitted(self)
# --> 896 with _raise_or_warn_if_not_fitted(self):
#     897     Xt = X
#     899     if not _routing_enabled():
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2288.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\pipeline.py:60, in _raise_or_warn_if_not_fitted(estimator)
#      58 # we only get here if the above didn't raise
#      59 try:
# ---> 60     check_is_fitted(estimator)
#      61 except NotFittedError:
#      62     warnings.warn(
#      63         "This Pipeline instance is not fitted yet. Call 'fit' with "
#      64         "appropriate arguments before using other methods such as transform, "
#    (...)
#      67         FutureWarning,
#      68     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1756, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1753 if not tags.requires_fit and attributes is None:
#    1754     return
# -> 1756 if not _is_fitted(estimator, attributes, all_or_any):
#    1757     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1665, in _is_fitted(estimator, attributes, all_or_any)
#    1662     return all_or_any([hasattr(estimator, attr) for attr in attributes])
#    1664 if hasattr(estimator, "__sklearn_is_fitted__"):
# -> 1665     return estimator.__sklearn_is_fitted__()
#    1667 fitted_attrs = [
#    1668     v for v in vars(estimator) if v.endswith("_") and not v.startswith("__")
#    1669 ]
#    1670 return len(fitted_attrs) > 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\pipeline.py:1310, in Pipeline.__sklearn_is_fitted__(self)
#    1303     return True
#    1305 try:
#    1306     # check if the last step of the pipeline is fitted
#    1307     # we only check the last step since if the last step is fit, it
#    1308     # means the previous steps should also be fit. This is faster than
#    1309     # checking if every step of the pipeline is fit.
# -> 1310     check_is_fitted(last_step)
#    1311     return True
#    1312 except NotFittedError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1751, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1748 if not hasattr(estimator, "fit"):
#    1749     raise TypeError("%s is not an estimator instance." % (estimator))
# -> 1751 tags = get_tags(estimator)
#    1753 if not tags.requires_fit and attributes is None:
#    1754     return
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_tags.py:405, in get_tags(estimator)
#     403 for klass in reversed(type(estimator).mro()):
#     404     if "__sklearn_tags__" in vars(klass):
# --> 405         sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     406         class_order.append(klass)
#     407     elif "_more_tags" in vars(klass):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:540, in ClassifierMixin.__sklearn_tags__(self)
#     539 def __sklearn_tags__(self):
# --> 540     tags = super().__sklearn_tags__()
#     541     tags.estimator_type = "classifier"
#     542     tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'

# %%
# %pip install XGBClassifier
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement XGBClassifier (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: C:\Users\62822\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for XGBClassifier
